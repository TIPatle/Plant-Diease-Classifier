# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# %%
IMAGE_SIZE = 256
BATCH_SIZE = 32
CHANNELS = 3
EPOCHS=50

# %%
dataset = tf.keras.utils.image_dataset_from_directory(
    "Plant",
    batch_size=BATCH_SIZE,
    image_size=(IMAGE_SIZE, IMAGE_SIZE),
    shuffle=True
)
# Out:
# Found 2152 files belonging to 3 classes.

# %%
type(dataset)
# Out:
# tensorflow.python.data.ops.batch_op._BatchDataset

# %%
classes = dataset.class_names
print(classes)
# Out:
# ['Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy']

# %%
plt.figure(figsize=(10, 10))
for image_batch, label_batch in dataset.take(1):
    for i in range(12):
        plt.subplot(3, 4, i+1)
        plt.title(classes[label_batch[i]])
        plt.imshow(image_batch[i].numpy().astype(int))
        plt.axis("off")

# %% [markdown]
# first len(dataset)*0.8 = 54 batches will be taken for tarining

# %%
train_size = int(len(dataset)*0.8)
train_ds = dataset.take(train_size)

# %%
val_size = int(len(dataset)*0.1)
validation_ds = dataset.skip(train_size).take(val_size)
test_batch = len(dataset) - train_size - val_size 
test_ds = dataset.skip(train_size+val_size)

# %%
print(train_size, len(test_ds), val_size)
# Out:
# 54 8 6

# %%
def split_dataset(ds, train_split=0.8, test_split=0.1, val_spilt=0.1, shuffle=True, shuffle_size=10000):
    ds_size = len(ds)
    train_size = int(ds_size*0.8)
    val_size = int(ds_size*0.1)
    test_size = ds_size - train_size - val_size
    
    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12)
    
    train_ds = ds.take(train_size)
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size+val_size)
    
    return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = split_dataset(dataset)

# %%
train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
resize_and_rescale = tf.keras.Sequential([
    tf.keras.layers.Resizing(IMAGE_SIZE, IMAGE_SIZE),
    tf.keras.layers.Rescaling(scale=1.0/255)
])

# %%
data_augment = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal_and_vertical"),
    tf.keras.layers.RandomRotation(0.2)
])

# %%
input_shape = (BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, CHANNELS)
n_classes = 3;
model = tf.keras.Sequential([
    resize_and_rescale,
    data_augment,
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape),
    tf.keras.layers.MaxPool2D((2, 2), 2),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPool2D((2, 2), 2),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPool2D((2, 2), 2),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPool2D((2, 2), 2),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPool2D((2, 2), 2),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPool2D((2, 2), 2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(n_classes, activation='softmax')
])
model.build(input_shape=input_shape)

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics='accuracy'
)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (32, 256, 256, 3)         0
#
#  sequential_1 (Sequential)   (32, 256, 256, 3)         0
#
#  conv2d (Conv2D)             (32, 254, 254, 32)        896
#
#  max_pooling2d (MaxPooling2D  (32, 127, 127, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (32, 125, 125, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (32, 62, 62, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (32, 60, 60, 64)          36928
#
#  max_pooling2d_2 (MaxPooling  (32, 30, 30, 64)         0
#  2D)
#
#  conv2d_3 (Conv2D)           (32, 28, 28, 64)          36928
#
#  max_pooling2d_3 (MaxPooling  (32, 14, 14, 64)         0
#  2D)
#
#  conv2d_4 (Conv2D)           (32, 12, 12, 64)          36928
#
#  max_pooling2d_4 (MaxPooling  (32, 6, 6, 64)           0
#  2D)
#
#  conv2d_5 (Conv2D)           (32, 4, 4, 64)            36928
#
#  max_pooling2d_5 (MaxPooling  (32, 2, 2, 64)           0
#  2D)
#
#  flatten (Flatten)           (32, 256)                 0
#
#  dense (Dense)               (32, 64)                  16448
#
#  dense_1 (Dense)             (32, 3)                   195
#
# =================================================================
# Total params: 183,747
# Trainable params: 183,747
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(
    train_ds,
    epochs=50,
    batch_size=32, 
    validation_data=val_ds,
)
# Out:
# Epoch 1/50
# 54/54 [==============================] - 70s 1s/step - loss: 0.8734 - accuracy: 0.5405 - val_loss: 0.7649 - val_accuracy: 0.6406
# Epoch 2/50
# 54/54 [==============================] - 60s 1s/step - loss: 0.5639 - accuracy: 0.7565 - val_loss: 0.6595 - val_accuracy: 0.6845
# Epoch 3/50
# 54/54 [==============================] - 60s 1s/step - loss: 0.4765 - accuracy: 0.7841 - val_loss: 0.3478 - val_accuracy: 0.8646
# Epoch 4/50
# 54/54 [==============================] - 59s 1s/step - loss: 0.3463 - accuracy: 0.8568 - val_loss: 0.2479 - val_accuracy: 0.8906
# Epoch 5/50
# 54/54 [==============================] - 62s 1s/step - loss: 0.3320 - accuracy: 0.8685 - val_loss: 0.2456 - val_accuracy: 0.9115
# Epoch 6/50
# 54/54 [==============================] - 59s 1s/step - loss: 0.2619 - accuracy: 0.8950 - val_loss: 0.2230 - val_accuracy: 0.9115
# Epoch 7/50
# 54/54 [==============================] - 62s 1s/step - loss: 0.1973 - accuracy: 0.9208 - val_loss: 0.1829 - val_accuracy: 0.9167
# Epoch 8/50
# 54/54 [==============================] - 60s 1s/step - loss: 0.1880 - accuracy: 0.9261 - val_loss: 0.2452 - val_accuracy: 0.9167
# Epoch 9/50
# 54/54 [==============================] - 59s 1s/step - loss: 0.1648 - accuracy: 0.9378 - val_loss: 0.2081 - val_accuracy: 0.9323
# Epoch 10/50
# 54/54 [==============================] - 59s 1s/step - loss: 0.1421 - accuracy: 0.9448 - val_loss: 0.1374 - val_accuracy: 0.9479
# Epoch 11/50
# 54/54 [==============================] - 790s 15s/step - loss: 0.1450 - accuracy: 0.9448 - val_loss: 0.2031 - val_accuracy: 0.9323
# Epoch 12/50
# 54/54 [==============================] - 57s 1s/step - loss: 0.1088 - accuracy: 0.9619 - val_loss: 0.2077 - val_accuracy: 0.9271
# Epoch 13/50
# 54/54 [==============================] - 59s 1s/step - loss: 0.1878 - accuracy: 0.9337 - val_loss: 0.1051 - val_accuracy: 0.9635
# Epoch 14/50
# 54/54 [==============================] - 59s 1s/step - loss: 0.0904 - accuracy: 0.9712 - val_loss: 0.2247 - val_accuracy: 0.9167
# Epoch 15/50
# 54/54 [==============================] - 59s 1s/step - loss: 0.0743 - accuracy: 0.9748 - val_loss: 0.0797 - val_accuracy: 0.9635
# Epoch 16/50
# 54/54 [==============================] - 59s 1s/step - loss: 0.0757 - accuracy: 0.9748 - val_loss: 0.0928 - val_accuracy: 0.9740
# Epoch 17/50
# 54/54 [==============================] - 63s 1s/step - loss: 0.0911 - accuracy: 0.9648 - val_loss: 0.1465 - val_accuracy: 0.9479
# Epoch 18/50
# 54/54 [==============================] - 63s 1s/step - loss: 0.0856 - accuracy: 0.9718 - val_loss: 0.1665 - val_accuracy: 0.9219
# Epoch 19/50
# 54/54 [==============================] - 62s 1s/step - loss: 0.0641 - accuracy: 0.9783 - val_loss: 0.0355 - val_accuracy: 0.9881
# Epoch 20/50
# 54/54 [==============================] - 61s 1s/step - loss: 0.0950 - accuracy: 0.9636 - val_loss: 0.2940 - val_accuracy: 0.9167
# Epoch 21/50
# 54/54 [==============================] - 61s 1s/step - loss: 0.0676 - accuracy: 0.9734 - val_loss: 0.0616 - val_accuracy: 0.9740
# Epoch 22/50
# 54/54 [==============================] - 59s 1s/step - loss: 0.0366 - accuracy: 0.9859 - val_loss: 0.0406 - val_accuracy: 0.9896
# Epoch 23/50
# 54/54 [==============================] - 61s 1s/step - loss: 0.0517 - accuracy: 0.9783 - val_loss: 0.0814 - val_accuracy: 0.9740
# Epoch 24/50
# 54/54 [==============================] - 64s 1s/step - loss: 0.0657 - accuracy: 0.9742 - val_loss: 0.0446 - val_accuracy: 0.9844
# Epoch 25/50
# 54/54 [==============================] - 60s 1s/step - loss: 0.0440 - accuracy: 0.9853 - val_loss: 0.0098 - val_accuracy: 1.0000
# Epoch 26/50
# 54/54 [==============================] - 63s 1s/step - loss: 0.0461 - accuracy: 0.9850 - val_loss: 0.2726 - val_accuracy: 0.9167
# Epoch 27/50
# 54/54 [==============================] - 64s 1s/step - loss: 0.0387 - accuracy: 0.9855 - val_loss: 0.0793 - val_accuracy: 0.9583
# Epoch 28/50
# 54/54 [==============================] - 63s 1s/step - loss: 0.0440 - accuracy: 0.9830 - val_loss: 0.0386 - val_accuracy: 0.9821
# Epoch 29/50
# 54/54 [==============================] - 62s 1s/step - loss: 0.0441 - accuracy: 0.9844 - val_loss: 0.0274 - val_accuracy: 0.9896
# Epoch 30/50
# 54/54 [==============================] - 59s 1s/step - loss: 0.0221 - accuracy: 0.9930 - val_loss: 0.2314 - val_accuracy: 0.9167
# Epoch 31/50
# 54/54 [==============================] - 59s 1s/step - loss: 0.0348 - accuracy: 0.9912 - val_loss: 0.0279 - val_accuracy: 0.9896
# Epoch 32/50
# 54/54 [==============================] - 66s 1s/step - loss: 0.0382 - accuracy: 0.9890 - val_loss: 0.0318 - val_accuracy: 0.9792
# Epoch 33/50
# 54/54 [==============================] - 61s 1s/step - loss: 0.0236 - accuracy: 0.9924 - val_loss: 0.0234 - val_accuracy: 0.9948
# Epoch 34/50
# 54/54 [==============================] - 60s 1s/step - loss: 0.0278 - accuracy: 0.9890 - val_loss: 0.0643 - val_accuracy: 0.9740
# Epoch 35/50
# 54/54 [==============================] - 59s 1s/step - loss: 0.0798 - accuracy: 0.9707 - val_loss: 0.1495 - val_accuracy: 0.9531
# Epoch 36/50
# 54/54 [==============================] - 58s 1s/step - loss: 0.0379 - accuracy: 0.9871 - val_loss: 0.0369 - val_accuracy: 0.9821
# Epoch 37/50
# 54/54 [==============================] - 59s 1s/step - loss: 0.0182 - accuracy: 0.9941 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 38/50
# 54/54 [==============================] - 60s 1s/step - loss: 0.0193 - accuracy: 0.9942 - val_loss: 0.0665 - val_accuracy: 0.9792
# Epoch 39/50
# 54/54 [==============================] - 62s 1s/step - loss: 0.0314 - accuracy: 0.9878 - val_loss: 0.0748 - val_accuracy: 0.9844
# Epoch 40/50
# 54/54 [==============================] - 59s 1s/step - loss: 0.0882 - accuracy: 0.9660 - val_loss: 0.1394 - val_accuracy: 0.9688
# Epoch 41/50
# 54/54 [==============================] - 58s 1s/step - loss: 0.0887 - accuracy: 0.9654 - val_loss: 0.1221 - val_accuracy: 0.9427
# Epoch 42/50
# 54/54 [==============================] - 58s 1s/step - loss: 0.0491 - accuracy: 0.9847 - val_loss: 0.1218 - val_accuracy: 0.9479
# Epoch 43/50
# 54/54 [==============================] - 58s 1s/step - loss: 0.0289 - accuracy: 0.9894 - val_loss: 0.1824 - val_accuracy: 0.9271
# Epoch 44/50
# 54/54 [==============================] - 58s 1s/step - loss: 0.0262 - accuracy: 0.9930 - val_loss: 0.0800 - val_accuracy: 0.9702
# Epoch 45/50
# 54/54 [==============================] - 58s 1s/step - loss: 0.0169 - accuracy: 0.9935 - val_loss: 0.0793 - val_accuracy: 0.9792
# Epoch 46/50
# 54/54 [==============================] - 58s 1s/step - loss: 0.0105 - accuracy: 0.9971 - val_loss: 0.1060 - val_accuracy: 0.9762
# Epoch 47/50
# 54/54 [==============================] - 59s 1s/step - loss: 0.0086 - accuracy: 0.9971 - val_loss: 0.2143 - val_accuracy: 0.9479
# Epoch 48/50
# 54/54 [==============================] - 58s 1s/step - loss: 0.0422 - accuracy: 0.9888 - val_loss: 0.0218 - val_accuracy: 0.9896
# Epoch 49/50
# 54/54 [==============================] - 58s 1s/step - loss: 0.0173 - accuracy: 0.9947 - val_loss: 0.0112 - val_accuracy: 0.9896
# Epoch 50/50
# 54/54 [==============================] - 58s 1s/step - loss: 0.0224 - accuracy: 0.9912 - val_loss: 0.0306 - val_accuracy: 0.9792

# %%
plt.figure(figsize=(12, 12))
for imageBatch, labelBatch in dataset.take(1):
    prediction = model.predict(imageBatch)
    for i in range(12):
        index = np.argmax(prediction[i])
        plt.subplot(4, 3, i+1)
        plt.title(f"Actual: {classes[label_batch[i]]}\nPredicted: {classes[index]}", fontsize=10)
        plt.imshow(image_batch[i].numpy().astype(int))
        plt.axis("off")
# Out:
# 1/1 [==============================] - 0s 198ms/step

# %%
model.evaluate(train_ds)
# Out:
# 54/54 [==============================] - 14s 241ms/step - loss: 0.0343 - accuracy: 0.9871
# [0.034301288425922394, 0.987089216709137]

# %%
plt.plot(history.history['accuracy'], c='red')
plt.plot(history.history['val_accuracy'], c='blue')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Model Training History")
# Out:
# Text(0.5, 1.0, 'Model Training History')

# %%
plt.plot(history.history['loss'], c='red')
plt.plot(history.history['val_loss'], c='blue')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Model Training History")
# Out:
# Text(0.5, 1.0, 'Model Training History')

# %%
model.evaluate(test_ds)
# Out:
# 8/8 [==============================] - 3s 231ms/step - loss: 0.0149 - accuracy: 0.9961
# [0.014926652424037457, 0.99609375]

# %%
def predict(model, img):
    image = tf.expand_dims(img, 0)
    prediction = model.predict(image)
    index = np.argmax(prediction[0])
    confidence = 100*prediction[0][index]
    return confidence, classes[index]

# %%
Image = 1;
for imagebatch, labelbatch in dataset.take(1):
    Image = imagebatch[0].numpy()

# %%
plt.imshow(Image.astype(int))
img_predict = predict(model, Image)
plt.title(f"Prediction: {img_predict[1]} \nConfidence: {img_predict[0] :.2f}")
# Out:
# 1/1 [==============================] - 0s 33ms/step
# Text(0.5, 1.0, 'Prediction: Potato___Late_blight \nConfidence: 99.99')

# %%
import os
